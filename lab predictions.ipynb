# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.preprocessing import MinMaxScaler 
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from datetime import datetime
from datetime import timedelta
from sklearn.linear_model import LogisticRegression
import pymysql                        # for getting data from a SQL database
from sqlalchemy import create_engine  # for establishing the connection and authentication
from getpass import getpass  # To get the

# %%
# prep: import modules and get pwd
import pymysql
from sqlalchemy import create_engine

import getpass  # To get the password without showing the input
password = getpass.getpass()
# Out:
# ········

# %%
# get the data
connection_string = 'mysql+pymysql://root:'+password+'@localhost/sakila'
engine = create_engine(connection_string)
query = '''SELECT f.title as film_title,
                f.film_id,
                  f.rental_duration,
                  f.rental_rate,
                  f.rating,
                  f.length,
                  f.replacement_cost,
                  COUNT(DISTINCT r.rental_id) AS rental_count,
                  COUNT(DISTINCT i.inventory_id) AS inventory_count,
                  COUNT(DISTINCT fa.actor_id) AS actor_count,
                  CASE 
                      WHEN f.title IN
                          (SELECT DISTINCT f.title as film_title
                           FROM film f
                           JOIN inventory i USING (film_id)
                           JOIN rental USING (inventory_id)
                           WHERE rental.rental_date LIKE "2005-05%%")
                      THEN "1"
                      ELSE "0"
                  END AS rented_in_may
          FROM film f
          LEFT JOIN inventory i USING (film_id)
          LEFT JOIN rental r USING (inventory_id)
          LEFT JOIN film_category fc USING (film_id)
          LEFT JOIN film_actor fa USING (film_id)
          GROUP BY f.film_id;'''



film = pd.read_sql_query(query, engine)
film
# Out:
#             film_title  film_id  rental_duration  rental_rate rating  length  \
# 0     ACADEMY DINOSAUR        1                6         0.99     PG      86
# 1       ACE GOLDFINGER        2                3         4.99      G      48
# 2     ADAPTATION HOLES        3                7         2.99  NC-17      50
# 3     AFFAIR PREJUDICE        4                5         2.99      G     117
# 4          AFRICAN EGG        5                6         2.99      G     130
# ..                 ...      ...              ...          ...    ...     ...
# 995     YOUNG LANGUAGE      996                6         0.99      G     183
# 996         YOUTH KICK      997                4         0.99  NC-17     179
# 997       ZHIVAGO CORE      998                6         0.99  NC-17     105
# 998  ZOOLANDER FICTION      999                5         2.99      R     101
# 999          ZORRO ARK     1000                3         4.99  NC-17      50
#
#      replacement_cost  rental_count  inventory_count  actor_count  \
# 0               20.99            23                8           10
# 1               12.99             7                3            4
# 2               18.99            12                4            5
# 3               26.99            23                7            5
# 4               22.99            12                3            5
# ..                ...           ...              ...          ...
# 995              9.99             7                2            5
# 996             14.99             6                2            5
# 997             10.99             9                2            6
# 998             28.99            17                5            5
# 999             18.99            31                8            3
#
#     rented_in_may
# 0               1
# 1               0
# 2               1
# 3               1
# 4               1
# ..            ...
# 995             0
# 996             0
# 997             1
# 998             1
# 999             1
#
# [1000 rows x 11 columns]

# %%
connection_string = 'mysql+pymysql://root:'+password+'@localhost/sakila'
engine = create_engine(connection_string)
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/sakila)

# %%
query1 = 'SELECT film_category.film_id, category.name AS category_name FROM sakila.film_category JOIN sakila.category USING (category_id)'
film_category = pd.read_sql_query(query1, engine)
film_category

film = pd.merge(left=film,right=film_category,how = 'inner',left_on = 'film_id', right_on='film_id')

film = film.drop("film_id", axis=1)
film
# Out:
#             film_title  rental_duration  rental_rate rating  length  \
# 0     ACADEMY DINOSAUR                6         0.99     PG      86
# 1       ACE GOLDFINGER                3         4.99      G      48
# 2     ADAPTATION HOLES                7         2.99  NC-17      50
# 3     AFFAIR PREJUDICE                5         2.99      G     117
# 4          AFRICAN EGG                6         2.99      G     130
# ..                 ...              ...          ...    ...     ...
# 995     YOUNG LANGUAGE                6         0.99      G     183
# 996         YOUTH KICK                4         0.99  NC-17     179
# 997       ZHIVAGO CORE                6         0.99  NC-17     105
# 998  ZOOLANDER FICTION                5         2.99      R     101
# 999          ZORRO ARK                3         4.99  NC-17      50
#
#      replacement_cost  rental_count  inventory_count  actor_count  \
# 0               20.99            23                8           10
# 1               12.99             7                3            4
# 2               18.99            12                4            5
# 3               26.99            23                7            5
# 4               22.99            12                3            5
# ..                ...           ...              ...          ...
# 995              9.99             7                2            5
# 996             14.99             6                2            5
# 997             10.99             9                2            6
# 998             28.99            17                5            5
# 999             18.99            31                8            3
#
#     rented_in_may category_name
# 0               1   Documentary
# 1               0        Horror
# 2               1   Documentary
# 3               1        Horror
# 4               1        Family
# ..            ...           ...
# 995             0   Documentary
# 996             0         Music
# 997             1        Horror
# 998             1      Children
# 999             1        Comedy
#
# [1000 rows x 11 columns]

# %%
numerical_columns= film.select_dtypes(include=[np.number]) 
numerical_columns.describe()
# Out:
#        rental_duration  rental_rate       length  replacement_cost  \
# count      1000.000000  1000.000000  1000.000000       1000.000000
# mean          4.985000     2.980000   115.272000         19.984000
# std           1.411654     1.646393    40.426332          6.050833
# min           3.000000     0.990000    46.000000          9.990000
# 25%           4.000000     0.990000    80.000000         14.990000
# 50%           5.000000     2.990000   114.000000         19.990000
# 75%           6.000000     4.990000   149.250000         24.990000
# max           7.000000     4.990000   185.000000         29.990000
#
#        rental_count  inventory_count  actor_count
# count   1000.000000      1000.000000  1000.000000
# mean      16.044000         4.581000     5.462000
# std        7.348065         2.020277     2.337524
# min        0.000000         0.000000     0.000000
# 25%       11.000000         3.000000     4.000000
# 50%       16.000000         5.000000     5.000000
# 75%       21.000000         6.000000     7.000000
# max       34.000000         8.000000    15.000000

# %%
categorical_columns = film.select_dtypes(include='object') #Solo columnas objeto
categorical_columns.describe()
# Out:
#         film_title rating rented_in_may category_name
# count         1000   1000          1000          1000
# unique        1000      5             2            16
# top     CRAZY HOME  PG-13             1        Sports
# freq             1    223           686            74

# %%
correlations_matrix = numerical_columns.corr()
sns.heatmap(correlations_matrix, annot=True)  #Mapa de calor de correlaciones
plt.show()

# %%
sns.displot(film['rental_duration'], kde=True)
plt.show()

sns.displot(film['rental_rate'], kde=True)
plt.show()

sns.displot(film['length'], kde=True)
plt.show()

sns.displot(film['replacement_cost'], kde=True)
plt.show()

sns.displot(film['rental_count'], kde=True)
plt.show()

sns.displot(film['inventory_count'], kde=True)
plt.show()

sns.displot(film['actor_count'], kde=True)
plt.show()

# %% [markdown]
# # DROPING FILM_TITLE AND RENTAL_COUNT

# %%
film = film.drop("film_title" , axis=1)
film
# Out:
#      rental_duration  rental_rate rating  length  replacement_cost  \
# 0                  6         0.99     PG      86             20.99
# 1                  3         4.99      G      48             12.99
# 2                  7         2.99  NC-17      50             18.99
# 3                  5         2.99      G     117             26.99
# 4                  6         2.99      G     130             22.99
# ..               ...          ...    ...     ...               ...
# 995                6         0.99      G     183              9.99
# 996                4         0.99  NC-17     179             14.99
# 997                6         0.99  NC-17     105             10.99
# 998                5         2.99      R     101             28.99
# 999                3         4.99  NC-17      50             18.99
#
#      rental_count  inventory_count  actor_count rented_in_may category_name
# 0              23                8           10             1   Documentary
# 1               7                3            4             0        Horror
# 2              12                4            5             1   Documentary
# 3              23                7            5             1        Horror
# 4              12                3            5             1        Family
# ..            ...              ...          ...           ...           ...
# 995             7                2            5             0   Documentary
# 996             6                2            5             0         Music
# 997             9                2            6             1        Horror
# 998            17                5            5             1      Children
# 999            31                8            3             1        Comedy
#
# [1000 rows x 10 columns]

# %%
film = film.drop("rental_count" , axis=1)
film
# Out:
#      rental_duration  rental_rate rating  length  replacement_cost  \
# 0                  6         0.99     PG      86             20.99
# 1                  3         4.99      G      48             12.99
# 2                  7         2.99  NC-17      50             18.99
# 3                  5         2.99      G     117             26.99
# 4                  6         2.99      G     130             22.99
# ..               ...          ...    ...     ...               ...
# 995                6         0.99      G     183              9.99
# 996                4         0.99  NC-17     179             14.99
# 997                6         0.99  NC-17     105             10.99
# 998                5         2.99      R     101             28.99
# 999                3         4.99  NC-17      50             18.99
#
#      inventory_count  actor_count rented_in_may category_name
# 0                  8           10             1   Documentary
# 1                  3            4             0        Horror
# 2                  4            5             1   Documentary
# 3                  7            5             1        Horror
# 4                  3            5             1        Family
# ..               ...          ...           ...           ...
# 995                2            5             0   Documentary
# 996                2            5             0         Music
# 997                2            6             1        Horror
# 998                5            5             1      Children
# 999                8            3             1        Comedy
#
# [1000 rows x 9 columns]

# %% [markdown]
# X,y split

# %%
y = film['rented_in_may']
X = film.drop('rented_in_may', axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=400)

# %% [raw]
# min max scaling

# %%
X_train_num = X_train.select_dtypes(include=[np.number])  
X_train_num
# Out:
#      rental_duration  rental_rate  length  replacement_cost  inventory_count  \
# 805                4         2.99     137             25.99                5
# 626                4         4.99      67              9.99                3
# 45                 3         4.99     108             13.99                3
# 868                4         2.99      47             22.99                7
# 799                7         2.99     126             19.99                6
# ..               ...          ...     ...               ...              ...
# 140                6         4.99     185             11.99                5
# 953                7         4.99      73             18.99                0
# 318                4         2.99     125             22.99                7
# 463                3         2.99     107             13.99                7
# 348                4         2.99     185             27.99                7
#
#      actor_count
# 805            6
# 626            5
# 45             3
# 868            8
# 799            4
# ..           ...
# 140            8
# 953            5
# 318            2
# 463            2
# 348            4
#
# [800 rows x 6 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
transformer = MinMaxScaler().fit(X_train_num)
X_train_normalized = transformer.transform(X_train_num)
X_train_norm = pd.DataFrame(X_train_normalized, columns=X_train_num.columns)
X_train_norm
# Out:
#      rental_duration  rental_rate    length  replacement_cost  \
# 0               0.25          0.5  0.654676              0.80
# 1               0.25          1.0  0.151079              0.00
# 2               0.00          1.0  0.446043              0.20
# 3               0.25          0.5  0.007194              0.65
# 4               1.00          0.5  0.575540              0.50
# ..               ...          ...       ...               ...
# 795             0.75          1.0  1.000000              0.10
# 796             1.00          1.0  0.194245              0.45
# 797             0.25          0.5  0.568345              0.65
# 798             0.00          0.5  0.438849              0.20
# 799             0.25          0.5  1.000000              0.90
#
#      inventory_count  actor_count
# 0              0.625     0.400000
# 1              0.375     0.333333
# 2              0.375     0.200000
# 3              0.875     0.533333
# 4              0.750     0.266667
# ..               ...          ...
# 795            0.625     0.533333
# 796            0.000     0.333333
# 797            0.875     0.133333
# 798            0.875     0.133333
# 799            0.875     0.266667
#
# [800 rows x 6 columns]

# %% [raw]
# Transform categorical into numerical with train data

# %%
X_train_categorical = X_train.select_dtypes(include = object)
X_train_cat = pd.get_dummies(X_train_categorical, 
                             columns=['rating', 'category_name'],
                             drop_first=True)
X_train_cat.head()
# Out:
#      rating_NC-17  rating_PG  rating_PG-13  rating_R  category_name_Animation  \
# 805             0          1             0         0                        0
# 626             1          0             0         0                        0
# 45              0          0             0         0                        0
# 868             0          1             0         0                        0
# 799             0          0             1         0                        0
#
#      category_name_Children  category_name_Classics  category_name_Comedy  \
# 805                       0                       0                     0
# 626                       0                       0                     0
# 45                        0                       0                     0
# 868                       0                       0                     0
# 799                       0                       0                     0
#
#      category_name_Documentary  category_name_Drama  category_name_Family  \
# 805                          0                    0                     0
# 626                          1                    0                     0
# 45                           0                    0                     0
# 868                          0                    0                     0
# 799                          0                    0                     0
#
#      category_name_Foreign  category_name_Games  category_name_Horror  \
# 805                      0                    0                     0
# 626                      0                    0                     0
# 45                       0                    1                     0
# 868                      0                    0                     0
# 799                      0                    0                     1
#
#      category_name_Music  category_name_New  category_name_Sci-Fi  \
# 805                    0                  1                     0
# 626                    0                  0                     0
# 45                     0                  0                     0
# 868                    0                  0                     0
# 799                    0                  0                     0
#
#      category_name_Sports  category_name_Travel
# 805                     0                     0
# 626                     0                     0
# 45                      0                     0
# 868                     0                     0
# 799                     0                     0

# %%
X_train_transformed = np.concatenate([X_train_norm, X_train_cat], axis=1)

# %% [markdown]
# # Logistic regression model

# %%
classification = LogisticRegression(random_state=0,
                  multi_class='multinomial').fit(X_train_transformed, y_train)

# %%
# for numericals
X_test_num = X_test.select_dtypes(include = np.number)

# Scaling data
# we use the transformer that was trained on the training data
X_test_normalized = transformer.transform(X_test_num)
X_test_norm = pd.DataFrame(X_test_normalized)
X_test_norm.head()
# Out:
#       0    1         2     3      4         5
# 0  0.50  0.0  0.683453  0.00  0.875  0.333333
# 1  0.25  0.5  0.496403  0.20  0.375  0.466667
# 2  0.25  0.5  0.431655  0.05  0.750  0.333333
# 3  0.50  1.0  0.669065  0.85  0.875  0.266667
# 4  0.00  1.0  0.956835  0.90  1.000  0.333333

# %%
# for categoricals
X_test_categorical = X_test.select_dtypes(include = object)
X_test_cat = pd.get_dummies(X_test_categorical, 
                            columns=['rating', 'category_name'],
                            drop_first=True)

# %%
X_test_cat.head()
# Out:
#      rating_NC-17  rating_PG  rating_PG-13  rating_R  category_name_Animation  \
# 862             0          0             0         1                        0
# 699             0          0             0         1                        0
# 350             0          1             0         0                        0
# 243             1          0             0         0                        0
# 896             0          0             0         0                        0
#
#      category_name_Children  category_name_Classics  category_name_Comedy  \
# 862                       0                       0                     0
# 699                       0                       0                     0
# 350                       0                       0                     0
# 243                       0                       0                     0
# 896                       0                       0                     0
#
#      category_name_Documentary  category_name_Drama  category_name_Family  \
# 862                          0                    0                     0
# 699                          0                    0                     1
# 350                          0                    0                     0
# 243                          0                    0                     0
# 896                          0                    1                     0
#
#      category_name_Foreign  category_name_Games  category_name_Horror  \
# 862                      0                    0                     0
# 699                      0                    0                     0
# 350                      0                    0                     1
# 243                      0                    0                     0
# 896                      0                    0                     0
#
#      category_name_Music  category_name_New  category_name_Sci-Fi  \
# 862                    0                  0                     1
# 699                    0                  0                     0
# 350                    0                  0                     0
# 243                    1                  0                     0
# 896                    0                  0                     0
#
#      category_name_Sports  category_name_Travel
# 862                     0                     0
# 699                     0                     0
# 350                     0                     0
# 243                     0                     0
# 896                     0                     0

# %%
list(zip(list(X_train_cat.columns),list(X_test_cat.columns)))
# Out:
# [('rating_NC-17', 'rating_NC-17'),
#  ('rating_PG', 'rating_PG'),
#  ('rating_PG-13', 'rating_PG-13'),
#  ('rating_R', 'rating_R'),
#  ('category_name_Animation', 'category_name_Animation'),
#  ('category_name_Children', 'category_name_Children'),
#  ('category_name_Classics', 'category_name_Classics'),
#  ('category_name_Comedy', 'category_name_Comedy'),
#  ('category_name_Documentary', 'category_name_Documentary'),
#  ('category_name_Drama', 'category_name_Drama'),
#  ('category_name_Family', 'category_name_Family'),
#  ('category_name_Foreign', 'category_name_Foreign'),
#  ('category_name_Games', 'category_name_Games'),
#  ('category_name_Horror', 'category_name_Horror'),
#  ('category_name_Music', 'category_name_Music'),
#  ('category_name_New', 'category_name_New'),
#  ('category_name_Sci-Fi', 'category_name_Sci-Fi'),
#  ('category_name_Sports', 'category_name_Sports'),
#  ('category_name_Travel', 'category_name_Travel')]

# %%
list(X_train_cat.columns)==list(X_test_cat.columns)
# Out:
# True

# %%
X_test_transformed = np.concatenate([X_test_norm, X_test_cat], axis=1)

# %%
predictions = classification.predict(X_test_transformed)
predictions
classification.score(X_test_transformed, y_test)
# Out:
# 0.775

# %%
print(y_test.value_counts())
# Out:
# 1    142
# 0     58
# Name: rented_in_may, dtype: int64

# %%
pd.Series(predictions).value_counts()
# Out:
# 1    173
# 0     27
# dtype: int64

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, predictions)
# Out:
# array([[ 20,  38],
#        [  7, 135]], dtype=int64)

# %%
from sklearn import neighbors
clf = neighbors.KNeighborsClassifier(n_neighbors=3, weights='uniform')
clf.fit(X_train_transformed, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
predictions_clf = clf.predict(X_test_transformed)
clf.score(X_test_transformed, y_test)
# Out:
# 0.625

# %%
confusion_matrix(y_test, predictions_clf)
# Out:
# array([[ 14,  44],
#        [ 31, 111]], dtype=int64)
